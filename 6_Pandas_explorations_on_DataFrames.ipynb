# %% [markdown]
# # Pandas `DataFrame` operations: an exploration

# %%
import pandas as pd

# %%
index = pd.date_range('1/1/2000', periods=4, freq='T')

# %%
series = pd.Series([0.0, 5.0, 2.0, 3.0], index=index)

# %%
df = pd.DataFrame({'s': series})
df
# Out:
#                        s
# 2000-01-01 00:00:00  0.0
# 2000-01-01 00:01:00  5.0
# 2000-01-01 00:02:00  2.0
# 2000-01-01 00:03:00  3.0

# %%
df.asfreq(freq='15S', method='bfill')
# Out:
#                        s
# 2000-01-01 00:00:00  0.0
# 2000-01-01 00:00:15  5.0
# 2000-01-01 00:00:30  5.0
# 2000-01-01 00:00:45  5.0
# 2000-01-01 00:01:00  5.0
# 2000-01-01 00:01:15  2.0
# 2000-01-01 00:01:30  2.0
# 2000-01-01 00:01:45  2.0
# 2000-01-01 00:02:00  2.0
# 2000-01-01 00:02:15  3.0
# 2000-01-01 00:02:30  3.0
# 2000-01-01 00:02:45  3.0
# 2000-01-01 00:03:00  3.0

# %%
df.asfreq(freq='15S', method='pad')
# Out:
#                        s
# 2000-01-01 00:00:00  0.0
# 2000-01-01 00:00:15  0.0
# 2000-01-01 00:00:30  0.0
# 2000-01-01 00:00:45  0.0
# 2000-01-01 00:01:00  5.0
# 2000-01-01 00:01:15  5.0
# 2000-01-01 00:01:30  5.0
# 2000-01-01 00:01:45  5.0
# 2000-01-01 00:02:00  2.0
# 2000-01-01 00:02:15  2.0
# 2000-01-01 00:02:30  2.0
# 2000-01-01 00:02:45  2.0
# 2000-01-01 00:03:00  3.0

# %%
import matplotlib.pyplot as plt 

plt.plot(df.asfreq(freq='15S', method='pad'))
plt.show()

# %%
import pyodide
good_place_scripts = pyodide.open_url('https://raw.githubusercontent.com/dynamicwebpaige/nanowrimo-2021/main/data/scripts.csv')

# %%
good_place_dialogue = pd.read_csv(good_place_scripts)

# %%
good_place_dialogue.loc[good_place_dialogue['character'] == "Eleanor Shellstrop"]['line']
# Out:
# 5                                               I'm great.
# 6                                       Thanks for asking.
# 7                                        Oh, one question.
# 8                                              Where am I?
# 9                        Who are you, and what's going on?
#                                ...
# 24750                       The wave returns to the ocean.
# 24751    What the ocean does with the water after that ...
# 24752    But as a very wise not-robot once told me, "Th...
# 24754             Only if you say that thing I taught you.
# 24756                                         There we go.
# Name: line, Length: 5392, dtype: object

# %%
[print(i) for i in good_place_dialogue.loc[good_place_dialogue['character'] == "Chidi Anagonye"]['line']]
# Out:
# Eleanor?
# I'm Chidi Anagonye, and you are my soulmate.
# Well, I was born in Nigeria, raised in Senegal, but my work took me all over the place.
# Australia, Hong Kong, Paris.
# What about you?
# Mmm-hmm.
# Oh!
# I'm actually speaking French.
# This place just translates whatever you say into a language the other person can understand.
# So it's incredible.
# And now I want to say this.
# Eleanor.
# I have spent my entire life in pursuit of fundamental truths about the universe.
# And now we can actually learn about them together as soulmates.
# It's overwhelming.
# Of course I will.
# Eleanor, I swear that I will never say or do anything to cause you any harm.
# Wait, what?
# Are you sure this isn't you?
# If you're trying to curse, you can't here.
# I guess a lot of people in this neighborhood don't like it, so it's prohibited.
# So, if you're not this person, then who are you?
# What did you do for a living?
# So your job was to defraud the elderly�
# ...

# %%
good_place_dialogue['character'].unique()
# Out:
# array(['Michael', 'Eleanor Shellstrop', 'Chidi Anagonye', 'Wallace',
#        'Janet', 'Woman', 'Tahani Al-Jamil', 'Joe', 'Bambadjan', 'Gloria',
#        'Sachveer', 'Gary', 'Betsy', 'Man 1', 'Man 2', 'Man 3', 'Man 4',
#        'Jessica', 'Antonio', 'Gunnar', 'Pevita', 'Kirk', 'Samuel', 'Andy',
#        'Glenn', 'Cualli', 'Jason Mendoza', 'AcidCat', 'Chef Patricia',
#        'Pillboi', 'Young Tahani', 'Manisha Al-Jamil', 'Young Kamilah',
#        'Waqas Al-Jamil', 'Henriette', 'Kamilah Al-Jamil', 'Nina', 'Bart',
#        'Eunice', 'Paula Ouncerock', 'Brittany', 'Waitress', 'Henry',
#        'Allesandra', 'Madison', 'Trevor', 'Alexis', 'Good Place Woman',
#        'All', 'Real Eleanor', 'Todd', 'Bad Janet', 'Dana', 'Troy', 'Chad',
#        'Casey', "Casey's Friend", "Nixon's Voice", 'Dwayne DeRock',
#        'Young Uzo', 'Young Chidi', 'Kid', 'Zach Czytchu', 'Margaret',
#        'Deirdre', 'Uzo', 'Gawlff', 'Pilar', 'Susan',
# ...
