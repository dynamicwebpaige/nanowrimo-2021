# %%
import micropip
await micropip.install('pimondrian')

# %%
from IPython.display import display
from PIL import Image

# %%
import pimondrian
import matplotlib.pyplot as plt 

iterator = pimondrian.pi_generator()
colors = pimondrian.default_colors()
my_painting = pimondrian.Painting(5, iterator)
my_painting.save_png(4, colors, (1200, 800), "PiMondrian")
display(Image.open('PiMondrian.png'))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1200x800 at 0x353FE90>
